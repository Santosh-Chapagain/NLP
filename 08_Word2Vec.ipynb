# %%
import gensim 
from gensim.models import Word2Vec, KeyedVectors

# %%
# !pip install wget
# Out:
# ...
#   Using cached wget-3.2.zip (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9711 sha256=0c373df99d2e3867dcf26404e946084441a3526df3224e2ac79a25ca79e4796e
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# You do not need a file path when using api.load("word2vec-google-news-300").
# If you downloaded the raw GoogleNews binary yourself, replace the line below with the real .bin file path.
print(api.BASE_DIR)
# Out:
# C:\Users\Acer/gensim-data

# %%
from pathlib import Path

google_news_path = Path("C:/Users/Acer/Downloads/GoogleNews-vectors-negative300.bin")
if google_news_path.exists():
    model = KeyedVectors.load_word2vec_format(str(google_news_path), binary=True, limit=500000)
else:
    print(f"File not found: {google_news_path}")
    print("Use the actual .bin file path here, not the gensim-data folder.")
# Out:
# File not found: C:\Users\Acer\Downloads\GoogleNews-vectors-negative300.bin
# Use the actual .bin file path here, not the gensim-data folder.

# %%
import gensim.downloader as api
from pathlib import Path

cache_dir = Path(api.BASE_DIR)
print(cache_dir)
for path in cache_dir.rglob('*GoogleNews*'):
    print(path)
