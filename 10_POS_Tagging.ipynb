# %%
import spacy

# %%
nlp= spacy.load('en_core_web_sm')

# %%
doc= nlp(u"I am from Nepal. Where are you from ?")

# %%
doc.text
# Out:
# 'I am from Nepal. Where are you from ?'

# %%
doc[5].pos_
# Out:
# 'SCONJ'

# %%
spacy.explain('SCONJ')
# Out:
# 'subordinating conjunction'

# %%
for word in doc:
    print(word , " --> ",  word.pos_, "(", spacy.explain(word.pos_),")")
# Out:
# I  -->  PRON ( pronoun )
# am  -->  AUX ( auxiliary )
# from  -->  ADP ( adposition )
# Nepal  -->  PROPN ( proper noun )
# .  -->  PUNCT ( punctuation )
# Where  -->  SCONJ ( subordinating conjunction )
# are  -->  AUX ( auxiliary )
# you  -->  PRON ( pronoun )
# from  -->  ADP ( adposition )
# ?  -->  PUNCT ( punctuation )
